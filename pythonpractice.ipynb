# %% [markdown]
# <a href="https://colab.research.google.com/github/kamal-ganwani/python_basic_practice/blob/main/pythonpractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20
print(a+b) #for addition
print(a-b) # for substraction
print(a*b) #for multiple
print(a/b) #for divide
print(a%3) # for remainder value
print(b%3) # for remainder value
print(a**b) #for exponenet or square root value
print(a//b) # floor division
x=a+3 #assignmnt operator practice
print(x) #assignmnt operator practice
b+=3 #assignmnt operator practice
print(b) #assignmnt operator practice
b-=3 #assignmnt operator practice
print(b) #assignmnt operator practice
b*=3 #assignmnt operator practice
print(b) #assignmnt operator practice
b/=3 #assignmnt operator practice
print(b) #assignmnt operator practice
b%=3 #assignmnt operator practice
print(b) #assignmnt operator practice
b**=3 #assignmnt operator practice
print(b) #assignmnt operator practice
b//=3 #assignmnt operator practice
print(b) #assignmnt operator practice
print(a==b) #comparison operator practice
print(a!=b) #comparison operator practice
print(a>b) #comparison operator practice
print(a<b) #comparison operator practice
print(a>=b) #comparison operator practice
print(a<=b) #comparison operator practice
print(a is b) #identity operator practice
print(a is not b) #identity operator practice
print(a in [1,2,3,4,5]) #membership operator practice
print(b not in [1,2,3,4,5]) #membership operator practice
print(a and b) #logical operator practice
print(a or b) #logical operator practice
print(not a) #logical operator practice
print(not b) #logical operator practice
print (x<b and x>b) #logical operator practice
print(x<b or x>b) #logical operator practice
print(not(x<b or x>b)) #logical operator practice
string=('my first PYTHON test') #Membership operator practice
print('r' in string) #Membership operator practice
print('k' not in string) #Membership operator practice
print('k' in string) #Membership operator practice
print('r' not in string) #Membership operator practice
g=10 #identity operator practice
h=10 #identity operator practice
print(g is h, g==h) #identity operator practice
print(g is not h, g!=h) #identity operator practice
O=10 # bitwase operator practice
p=20 # bitwase operator practice
print(bin(O)) # bitwase operator practice
print(bin(p)) # bitwase operator practice
print(O&p, bin(O&p)) # bitwase operator practice
print(O|p, bin(O|p)) # bitwase operator practice
print(O^p), bin(O^p) # bitwase operator practice
print(~O), bin(O&p) # bitwase operator practice
# Out:
# 30
# -10
# 200
# 0.5
# 1
# 2
# 100000000000000000000
# 0
# 13
# 23
# 20
# 60
# 20.0
# 2.0
# 8.0
# 2.0
# False
# True
# True
# False
# True
# False
# False
# True
# False
# False
# 2.0
# 10
# False
# False
# False
# True
# False
# True
# True
# False
# False
# True True
# False False
# 0b1010
# 0b10100
# 0 0b0
# 30 0b11110
# 30
# -11
# (None, '0b0')

# %%
a=5
print(a, type(a)) #simple int number immutable
a=5.5
print(a, type(a)) #float number immutable
a=5+5j
print(a, type(a)) #complex number immutable
a=5.5+5.5j
print(a, type(a)) #complex number immutable

s='single quote string'
print(s, type(s)) #Single Quate string immutable
s="double quote string"
print(s, type(s)) #double Quate string immutable
s='''
triple
quote
string
'''
print(s, type(s)) #triple Quate string immutable
s="""triple quote string"""

l=[1,'list is mutable',3,4,'first list']
print(l, type(l)) #list mutable
l[1]='first list'
print(l, type(l)) #changing the list elemt at the index vlaue 1, value will be changed
l[4]='list is mutable'
print(l, type(l)) #changing the list elemt at the index vlaue 4, value will be changed
t=(1,'tuple is immutable',3,4,'first tuple')
print(t, type(t)) #tuple immutable
t=(1,'tuple is immutable',3,4,'first tuple')
t=(2)
print(t, type(t)) #tuple immutable, values cannot be modiified in tuple.
t=(1,'tuple is immutable',3,4,'first tuple')
#t[1]='first tuple'
print(t, type(t)) #tuple immutable, values cannot be modiified in tuple.
t=(1,'tuple is immutable',3,4,'first tuple')
print(t, type(t)) #tuple immutable

#dictionary datatype in python starts
d={
'course_name_key':'distionary testing',
'course_duration_key':'4 hours'
}
print(d['course_name_key'])
print(d['course_duration_key'])
print(d, type(d))

#dictionary datatype in python ends

#SET datatype in python starts
s={10,30, 50, 10, 60}
print(s)
print(s, type(s))

#SET datatype in python ends

# %%
from pickle import FLOAT
import gspread
#from gspread_service_account import service_account
#from google.colab import auth
#from google.auth import default
#auth.authenticate_user()
#gc = service_account(filename='pythoninput.json')
#sheet = gc.open('pythoninput')
#worksheet = sheet.get_worksheet(0)
#row_num = worksheet.get_row_count() + 1
#worksheet.update_cell(row_num, 1, input)
#sheet.update_cells(worksheet.get_all_cells())
#taking simple input from user START
a=input("this is simple input string or any numberint, float. NO TYPECAST")
b=input("this is simple input string or any numberint, float. NO TYPECAST")
print(a)
print(b)
print("simple input CONCATENED VALUE NO TYPE CASTING",a+b)
#taking simple input from user ENDS

#taking simple input from user START TYPE CASTING STRING INTO INT
a=int(input("INT TYPECASTING Here"))
b=int(input("INT TYPECASTING Here"))
print(a)
print(b)
print("type casted INT VALUE",a+b)

#taking simple input from user ENDS TYPE CASTING STRING INTO INT

#taking simple input from user START TYPE CASTING STRING INTO FLOAT
a=float(input("FLOAT TYPECASTING Here"))
b=float(input("FLOAT TYPECASTING Here"))
print(a)
print(b)
print("type casted FLOAT VALUE",a+b)

#taking simple input from user ENDS TYPE CASTING STRING INTO FLOAT

#taking simple input from user START TYPE CASTING STRING INTO EVAL
a=eval(input("EVAL TYPECASTING Here"))
b=eval(input("EVAL TYPECASTING Here"))
c=eval(input("EVAL TYPECASTING here for Binary Value"))
print(a)
print(b,type(b))
print(c,type(c))
print("type casted eval VALUE",a+b+c)

#taking simple input from user ENDS TYPE CASTING STRING INTO EVAL
